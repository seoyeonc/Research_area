# %%
import pandas as pd

# %%
javascript:void(0)

# %%
pd.read_csv('./dataset/대검찰청_범죄발생월_20171231.csv', encoding='cp949')
# Out:
#                         범죄분류     1월     2월     3월     4월     5월     6월     7월  \
# 0                         절도  14465  12829  15376  15402  17096  17061  16760
# 1                         장물    211    186    162    167    170    134    126
# 2                         사기  22208  18731  21351  19702  19621  19835  20407
# 3                         횡령   4770   3580   4109   4270   4708   4635   4738
# 4                         배임    620    369    474    408    440    440    437
# ..                       ...    ...    ...    ...    ...    ...    ...    ...
# 157               화물자동차운수사업법     92    112    156    215    230    246    200
# 158      화재로인한재해보상과보험가입에관한법률      0      2      2      1      2      2      0
# 159  화재예방·소방시설설치유지및안전관리에관한법률      4      3      2      1      3      2      2
# 160                  화학물질관리법    103     35     51     62     57     58     50
# 161                    기타특별법   4330   3852   5765   4349   4041   4313   4248
#
# ...
